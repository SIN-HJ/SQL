# %%
import sqlalchemy

# %%
# %load_ext sql
# %sql oracle://scott:tiger@localhost:1521/orcl

# %% [markdown]
# 문제 1. 이름과 월급과 직업을 출력하시오.

# %%
# %%sql
# select ename, sal, job
#    from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [('KING', Decimal('5000'), 'PRESIDENT'),
#  ('BLAKE', Decimal('2850'), 'MANAGER'),
#  ('CLARK', Decimal('2450'), 'MANAGER'),
#  ('JONES', Decimal('2975'), 'MANAGER'),
#  ('MARTIN', Decimal('1250'), 'SALESMAN'),
#  ('ALLEN', Decimal('1600'), 'SALESMAN'),
#  ('TURNER', Decimal('1500'), 'SALESMAN'),
#  ('JAMES', Decimal('950'), 'CLERK'),
#  ('WARD', Decimal('1250'), 'SALESMAN'),
#  ('FORD', Decimal('3000'), 'ANALYST'),
#  ('SMITH', Decimal('800'), 'CLERK'),
#  ('SCOTT', Decimal('3000'), 'ANALYST'),
#  ('ADAMS', Decimal('1100'), 'CLERK'),
#  ('MILLER', Decimal('1300'), 'CLERK')]

# %% [markdown]
# 문제 2. 이름, 입사일과 부서번호를 출력하시오.

# %%
# %%sql
# select ename, hiredate, deptno
#    from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [('KING', datetime.datetime(1981, 11, 17, 0, 0), 10),
#  ('BLAKE', datetime.datetime(1981, 5, 1, 0, 0), 30),
#  ('CLARK', datetime.datetime(1981, 5, 9, 0, 0), 10),
#  ('JONES', datetime.datetime(1981, 4, 1, 0, 0), 20),
#  ('MARTIN', datetime.datetime(1981, 9, 10, 0, 0), 30),
#  ('ALLEN', datetime.datetime(1981, 2, 11, 0, 0), 30),
#  ('TURNER', datetime.datetime(1981, 8, 21, 0, 0), 30),
#  ('JAMES', datetime.datetime(1981, 12, 11, 0, 0), 30),
#  ('WARD', datetime.datetime(1981, 2, 23, 0, 0), 30),
#  ('FORD', datetime.datetime(1981, 12, 11, 0, 0), 20),
#  ('SMITH', datetime.datetime(1980, 12, 9, 0, 0), 20),
#  ('SCOTT', datetime.datetime(1982, 12, 22, 0, 0), 20),
#  ('ADAMS', datetime.datetime(1983, 1, 15, 0, 0), 20),
#  ('MILLER', datetime.datetime(1982, 1, 11, 0, 0), 10)]

# %% [markdown]
# 문제 3. emp 테이블의 컬럼이 무엇무엇이 있는지 확인하시오

# %%
# %%sql
# describe emp

# %%
문제 4. 이름, 월급, 커미션을 출력하시오.

# %%
# %%sql
# select ename, sal, comm
#    from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [('KING', Decimal('5000'), None),
#  ('BLAKE', Decimal('2850'), None),
#  ('CLARK', Decimal('2450'), None),
#  ('JONES', Decimal('2975'), None),
#  ('MARTIN', Decimal('1250'), Decimal('1400')),
#  ('ALLEN', Decimal('1600'), Decimal('300')),
#  ('TURNER', Decimal('1500'), Decimal('0')),
#  ('JAMES', Decimal('950'), None),
#  ('WARD', Decimal('1250'), Decimal('500')),
#  ('FORD', Decimal('3000'), None),
#  ('SMITH', Decimal('800'), None),
#  ('SCOTT', Decimal('3000'), None),
#  ('ADAMS', Decimal('1100'), None),
#  ('MILLER', Decimal('1300'), None)]

# %%
문제 5. 이름, 직업, 입사일, 부서번호를 출력하시오

# %%
# %%sql
# select ename, job, hiredate, deptno
#    from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [('KING', 'PRESIDENT', datetime.datetime(1981, 11, 17, 0, 0), 10),
#  ('BLAKE', 'MANAGER', datetime.datetime(1981, 5, 1, 0, 0), 30),
#  ('CLARK', 'MANAGER', datetime.datetime(1981, 5, 9, 0, 0), 10),
#  ('JONES', 'MANAGER', datetime.datetime(1981, 4, 1, 0, 0), 20),
#  ('MARTIN', 'SALESMAN', datetime.datetime(1981, 9, 10, 0, 0), 30),
#  ('ALLEN', 'SALESMAN', datetime.datetime(1981, 2, 11, 0, 0), 30),
#  ('TURNER', 'SALESMAN', datetime.datetime(1981, 8, 21, 0, 0), 30),
#  ('JAMES', 'CLERK', datetime.datetime(1981, 12, 11, 0, 0), 30),
#  ('WARD', 'SALESMAN', datetime.datetime(1981, 2, 23, 0, 0), 30),
#  ('FORD', 'ANALYST', datetime.datetime(1981, 12, 11, 0, 0), 20),
#  ('SMITH', 'CLERK', datetime.datetime(1980, 12, 9, 0, 0), 20),
#  ('SCOTT', 'ANALYST', datetime.datetime(1982, 12, 22, 0, 0), 20),
#  ('ADAMS', 'CLERK', datetime.datetime(1983, 1, 15, 0, 0), 20),
#  ('MILLER', 'CLERK', datetime.datetime(1982, 1, 11, 0, 0), 10)]

# %%
문제 6&7. emp 테이블, dept 테이블의 모든 컬럼을 출력하시오.

# %%
# %%sql
# select *
#    from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [(7839, 'KING', 'PRESIDENT', None, datetime.datetime(1981, 11, 17, 0, 0), Decimal('5000'), None, 10),
#  (7698, 'BLAKE', 'MANAGER', 7839, datetime.datetime(1981, 5, 1, 0, 0), Decimal('2850'), None, 30),
#  (7782, 'CLARK', 'MANAGER', 7839, datetime.datetime(1981, 5, 9, 0, 0), Decimal('2450'), None, 10),
#  (7566, 'JONES', 'MANAGER', 7839, datetime.datetime(1981, 4, 1, 0, 0), Decimal('2975'), None, 20),
#  (7654, 'MARTIN', 'SALESMAN', 7698, datetime.datetime(1981, 9, 10, 0, 0), Decimal('1250'), Decimal('1400'), 30),
#  (7499, 'ALLEN', 'SALESMAN', 7698, datetime.datetime(1981, 2, 11, 0, 0), Decimal('1600'), Decimal('300'), 30),
#  (7844, 'TURNER', 'SALESMAN', 7698, datetime.datetime(1981, 8, 21, 0, 0), Decimal('1500'), Decimal('0'), 30),
#  (7900, 'JAMES', 'CLERK', 7698, datetime.datetime(1981, 12, 11, 0, 0), Decimal('950'), None, 30),
# ...

# %%
# %%sql
# select *
#    from dept
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [(10, 'ACCOUNTING', 'NEW YORK'),
#  (20, 'RESEARCH', 'DALLAS'),
#  (30, 'SALES', 'CHICAGO'),
#  (40, 'OPERATIONS', 'BOSTON')]
