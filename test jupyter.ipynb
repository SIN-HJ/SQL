# %%
import cx_Oracle

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('oracle://scott:tiger@localhost:1521/orcl')

# %%
import cx_Oracle

# %%
indata = pd.read_sql_query("select * from emp", engine)
indata.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8adb37f02cf5> in <module>
# ----> 1 indata = pd.read_sql_query("select * from emp", engine)
#       2 indata.head()
#
# NameError: name 'pd' is not defined

# %%
# %sql oracle://scott:1234@localhost:1521/orcl
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\base.py:1368: SAWarning: Oracle version (19, 3, 0, 0, 0) is known to have a maximum identifier length of 128, rather than the historical default of 30. SQLAlchemy 1.4 will use 128 for this database; please set max_identifier_length=128 in create_engine() in order to test the application with this new length, or set to 30 in order to assure that 30 continues to be used.  In particular, pay close attention to the behavior of database migrations as dynamically generated names may change. See the section 'Max Identifier Lengths' in the SQLAlchemy Oracle dialect documentation for background.
#   util.warn(

# %%
# %sql
select * from emp
# Out:
#   File "<ipython-input-14-c9e02abbb522>", line 2
#     select * from emp
#              ^
# SyntaxError: invalid syntax

# %%
import sqlalchemy

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql oracle://scott:1234@localhost:1521/orcl

# %%
# %%sql
# select * from emp
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [(7839, 'KING', 'PRESIDENT', None, datetime.datetime(1981, 11, 17, 0, 0), Decimal('5000'), None, 10),
#  (7698, 'BLAKE', 'MANAGER', 7839, datetime.datetime(1981, 5, 1, 0, 0), Decimal('2850'), None, 30),
#  (7782, 'CLARK', 'MANAGER', 7839, datetime.datetime(1981, 5, 9, 0, 0), Decimal('2450'), None, 10),
#  (7566, 'JONES', 'MANAGER', 7839, datetime.datetime(1981, 4, 1, 0, 0), Decimal('2975'), None, 20),
#  (7654, 'MARTIN', 'SALESMAN', 7698, datetime.datetime(1981, 9, 10, 0, 0), Decimal('1250'), Decimal('1400'), 30),
#  (7499, 'ALLEN', 'SALESMAN', 7698, datetime.datetime(1981, 2, 11, 0, 0), Decimal('1600'), Decimal('300'), 30),
#  (7844, 'TURNER', 'SALESMAN', 7698, datetime.datetime(1981, 8, 21, 0, 0), Decimal('1500'), Decimal('0'), 30),
#  (7900, 'JAMES', 'CLERK', 7698, datetime.datetime(1981, 12, 11, 0, 0), Decimal('950'), None, 30),
# ...

# %%
# %%sql
# select * from emp12
# Out:
#  * oracle://scott:***@localhost:1521/orcl
# 0 rows affected.
# [('이준혁', 29, '남', '경영학과', 'kt', '3461419@naver.com', '경기도 안양시 동안구 호개동', 17000),
#  ('한결', 31, '남', '경제학과', 'kt', 'gksruf90@naver.com', '경기도 광주시 곤지암읍 삼리', 17000),
#  ('현지연', 35, '여', '관광경영학과', 'sk', 'hyunjy86@naver.com', '경기도 안산시 상록구 본삼로', 18500),
#  ('성기창', 29, '남', '경영학과', 'sk', 'goboy2005@gmail.com', '서울시 양천구 목5동', 18500),
#  ('유혜영', 28, '여', '응용통계학과', 'sk', 'jjku0519@naver.com', '경기도 안산시 단원구 고잔동', 18500),
#  ('김정민', 28, '남', '메카트로닉스과', 'lg', 'rlawjdals113@naver.com', '경기도 시흥시 은행동', 18000),
#  ('이성원', 25, '남', '통계학과', 'kt', 'pumadd1227@gmail.com', '경기도 성남시 수정구 고등동', 17000),
#  ('김정원', 28, '여', '수학통계학과', 'kt', 'jungwkim415@gmail.com', '경기도 성남시 분당구 정자동', 17000),
#  ('김미승', 27, '여', '금융학과', 'lg', 'miseung.hailey@gmail.com', '경기도 용인시 수지구 성복동', 18000),
#  ('김예린', 27, '여', '컨벤션경영학과', 'kt', 'marykim1205@naver.com', '경기도 성남시 분당구 운중동', 17000),
#  ('신현종', 27, '남', '병원행정학과', 'lg', 'ad_guswhd@naver.com', '경기도 성남시 중원구 성남동', 18000),
# ...
